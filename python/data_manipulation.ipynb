# %%
import pandas as pd

# %%
dict_area_airport = {
    'area_master' : ['aichi', 'akita', 'aomori', 'ehime', 'gihu', 'gunma', 'hiroshima', 'hokkaido', 'hukui', 'hukuoka', 'hukushima'    ,'hyogo' , 'ibaragi', 'ishikawa', 'iwate', 'kagawa', 'kagoshima', 'kanagawa', 'kouchi', 'kumamoto', 'kyoto', 'mie', 'miyagi', 'miyazaki', 'nagano', 'nagasaki' , 'nara' , 'niigata', 'okayama', 'okinawa', 'ooita', 'osaka' ,'saga' , 'saitama', 'shiga', 'shizuoka', 'simane', 'tiba' , 'tochigi', 'tokushima', 'tokyo', 'tottori', 'toyama', 'wakayama', 'yamagata', 'yamaguchi', 'yamanasi'],
    'area_rat'    : ['Aichi', 'Akita', ''      , 'Ehime', 'Gifu', 'Gumma', ''         , 'Hokkaido', 'Fukui', 'Fukuoka', 'Fukushima'    ,'Hyogo' , 'Ibaraki', ''        , ''     , 'Kagawa', 'Kagoshima', 'Kanagawa', ''      , ''        , 'Kyoto', 'Mie', 'Miyagi', 'Miyazaki', 'Nagano', ''         , 'Nara' , ''       , 'Okayama', 'Okinawa', 'Oita' , 'Osaka' ,''     , 'Saitama', 'Shiga', ''        , ''      , 'Chiba', ''       , ''         , 'Tokyo', ''       , 'Toyama', ''        , ''        , 'Yamaguchi', ''       ],
    'area_geo'    : ['Aichi',''      , ''      , 'Ehime', 'Gifu', 'Gunma', 'Hiroshima', 'Hokkaido', 'Fukui', 'Fukuoka', 'Fukushima-ken','Hyōgo' , 'Ibaraki', 'Ishikawa', 'Iwate', 'Kagawa', 'Kagoshima', 'Kanagawa', ''      , 'Kumamoto', 'Kyoto', 'Mie', ''      , 'Miyazaki', ''      , 'Nagasaki' , 'Nara' , 'Niigata', 'Okayama', 'Okinawa', 'Oita' , 'Ōsaka' ,'Saga' , 'Saitama', 'Shiga', 'Shizuoka' , ''      , 'Chiba', 'Tochigi', 'Tokushima', 'Tokyo', 'Tottori', 'Toyama', 'Wakayama', 'Yamagata', 'Yamaguchi', 'Yamanashi'],
    'airport_code': ['NGO'  ,''      , ''      , 'MYJ'  , 'NGO' , 'NRT'  , 'FUK'      , 'CTS'     , 'KIX'  , 'FUK'    , 'NRT'          ,'KIX'   , 'NRT'    , 'KMQ'     , 'NRT'  , 'TAK'   , 'FUK'      , 'HND'     , ''      , 'FUK'     , 'KIX'  , 'NGO', ''      , 'FUK'     , ''      , 'FUK'      , 'NRT'  , 'NRT'   , 'KIX'    , 'OKA'    , 'FUK'  , 'KIX'   , 'FUK' , 'NRT'    , 'KIX'  , 'NRT'      , ''      , 'NRT'  , 'HND'    , 'KIX'      , 'HND'  , 'KIX'    , 'NGO'   , 'KIX'     , 'SDJ'     , 'FUK'      , 'NRT']
}

# %%
pd.DataFrame(dict_area_airport)
# Out:
#    airport_code       area_geo area_master   area_rat
# 0           NGO          Aichi       aichi      Aichi
# 1                                    akita      Akita
# 2                                   aomori
# 3           MYJ          Ehime       ehime      Ehime
# 4           NGO           Gifu        gihu       Gifu
# 5           NRT          Gunma       gunma      Gumma
# 6           FUK      Hiroshima   hiroshima
# 7           CTS       Hokkaido    hokkaido   Hokkaido
# 8           KIX          Fukui       hukui      Fukui
# 9           FUK        Fukuoka     hukuoka    Fukuoka
# 10          NRT  Fukushima-ken   hukushima  Fukushima
# 11          KIX          Hyōgo       hyogo      Hyogo
# 12          NRT        Ibaraki     ibaragi    Ibaraki
# 13          KMQ       Ishikawa    ishikawa
# 14          NRT          Iwate       iwate
# 15          TAK         Kagawa      kagawa     Kagawa
# 16          FUK      Kagoshima   kagoshima  Kagoshima
# ...
